# %%
# !pip install geopandas
import geopandas as gpd
# Out:
# ...
#      |████████████████████████████████| 1.0 MB 3.1 MB/s
# ...
#      |████████████████████████████████| 16.7 MB 251 kB/s
# ...
#      |████████████████████████████████| 6.3 MB 39.6 MB/s
# ...

# %%
#can check the units bby checking the crs

# %%
countries = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
countries_attributes = countries[['name', 'iso_a3']]

# %%
cities = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))

# %%
europe = countries[countries['continent'] == "Europe"]
europe.plot(figsize=(8,8))

# %%
cities.plot()

# %%
#spatial join attempt, see notes
cities_in_europe = gpd.sjoin(cities, europe, op = "within")

# %%
countries.plot(figsize=(8,8))

# %%
#Dissolves
continent = countries.dissolve(by= "continent")
continent.plot(figsize=(8,8))

# %%
countries.plot()

# %%
countries.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
#Changing to Mercator Projection
countries_wo_antarctica = countries[(countries.name != "Antarctica") & (countries.name != "Fr. S. Antarctic Lands")]
countries2 = countries_wo_antarctica.to_crs(epsg=3395)
countries2.plot()
