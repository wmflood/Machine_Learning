# %%
import pandas as pd
#setting up dataframes

# %%
data=[['Clark', 11], ['Alex', 13]]
df = pd.DataFrame(data, columns=['name', 'age'])

# %%
print(df)
# Out:
#     name  age
# 0  Clark   11
# 1   Alex   13

# %%
data2 = {'names':['Bob', 'Tom'], 'age':[12,13]}
df2 = pd.DataFrame(data2)

# %%
print(df2)
# Out:
#   names  age
# 0   Bob   12
# 1   Tom   13

# %%
df3 = pd.read_csv('File_location/something.csv', header = None)
df3.head()

# %%
df3.columns = ["Course Code", "Course Title"]
df3.head()

# %%
record = df3.iloc[2]

# %%
df3['Course Title']

# %%
type(df2['age'])
# Out:
# pandas.core.series.Series

# %%
#filtering
df2[df2['age']>12]
# Out:
#   names  age
# 1   Tom   13

# %%
#installing and using GeoPandas
# !pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 1.0 MB 4.3 MB/s
# ...
#      |████████████████████████████████| 16.7 MB 352 kB/s
# ...
#      |████████████████████████████████| 6.3 MB 43.5 MB/s
# ...

# %%
import geopandas as gpd

# %%
world_shp = gpd.read_file("File_path/filename.shp")

# %%
world_shp.head(10)

# %%
#will create a default size map
world_shp.plot()
#can change the sizeif the map w/ figsize
#world_shp.colums will show all of the column titles in the shapefile
world_shp.crs #will give the epsg code for the file

# %%
gpd.datasets.available
# Out:
# ['naturalearth_cities', 'naturalearth_lowres', 'nybb']

# %%
ne_world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
ne_world.plot()

# %%
cities = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(10,8))
