# %%
# !pip install geopandas
import geopandas as gpd

# %%
# !pip install pandas fiona shapely pyproj rtree pygeos
import rtree
import pygeos

# %%
#Question 1
centroid_shp = gpd.read_file("SJER_plot_centroids.shp")
centroid_shp.crs
# Out:
# <Projected CRS: EPSG:32611>
# Name: WGS 84 / UTM zone 11N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 120°W and 114°W, northern hemisphere between equator and 84°N, onshore and offshore. Canada - Alberta; British Columbia (BC); Northwest Territories (NWT); Nunavut. Mexico. United States (USA).
# - bounds: (-120.0, 0.0, -114.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 11N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
#Name: WGS 84 / UTM zone 11N
#Units: Meter
#Datum: World Geodetic System 1984 ensemble
#Prime Meridian: Greenwich

# %%
#Question 2
crop_shp = gpd.read_file("SJER_crop.shp")
crop_shp.head()
# Out:
#    Id                                           geometry
# 0   0  POLYGON ((254570.567 4112361.920, 258867.409 4...

# %%
#there is one data record

# %%
#Question 3
centroid_crop_join = gpd.sjoin(centroid_shp, crop_shp)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-13e4f976dc2d> in <module>()
#       1 #Question 3
# ----> 2 centroid_crop_join = gpd.sjoin(centroid_shp, crop_shp)
#
# /usr/local/lib/python3.7/dist-packages/geopandas/tools/sjoin.py in sjoin(left_df, right_df, how, predicate, lsuffix, rsuffix, **kwargs)
#     122     _basic_checks(left_df, right_df, how, lsuffix, rsuffix)
#     123
# --> 124     indices = _geom_predicate_query(left_df, right_df, predicate)
#     125
#     126     joined = _frame_join(indices, left_df, right_df, how, lsuffix, rsuffix)
#
# /usr/local/lib/python3.7/dist-packages/geopandas/tools/sjoin.py in _geom_predicate_query(left_df, right_df, predicate)
#     214             # all other predicates are symmetric
#     215             # keep them the same
# --> 216             sindex = right_df.sindex
# ...
