# %%
a=3
b=4
a+b

print('Hello World')
# Out:
# Hello World

# %%
# !python --version
# Out:
# Python 3.7.12

# %%
def function (x):
  return x+3

# %%
function (7)
# Out:
# 10

# %%
def try_this (x,y):
  if x >= 7:
    return 'Yes'
  else:
    return x + y

# %%
try_this (8, 4)
# Out:
# 'Yes'

# %%
a = ['dog', 'cat', 'lizard', 'snake', 'turtle', 'ferret', 'dragon']

# %%
def some_stuff (lst):
  for animal in lst:
    if animal == 'dragon':
      return "Yikes"
  return "Cool"

# %%
some_stuff(a)
# Out:
# 'Yikes'
