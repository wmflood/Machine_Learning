# %%
# !pip install rasterio
import rasterio as ro

# %%
dataset = ro.open("Letch.tif")

# %%
dataset.bounds

# %%
dataset.transform

# %%
#shows the geo coordinates for an image upper left corner
dataset.transform * (0,0)

# %%
#shows the bottom left corner
dataset.transform * (0, dataset.height-1)

# %%
red = dataset.read(1)

# %%
#gives the index for the row and column
dataset.index(Geo_x, Geo_y)
